# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install selenium webdriver-manager

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service

# Automatically install the correct ChromeDriver version
service = Service(ChromeDriverManager().install())

# Launch Chrome using the installed driver
driver = webdriver.Chrome(service=service)

# Open a test webpage
driver.get("https://www.google.com")

# Print page title
print("Page title:", driver.title)

# Close browser
driver.quit()
# Out:
# Page title: Google

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time
service = Service(ChromeDriverManager().install())
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized")  

driver = webdriver.Chrome(service=service, options=options)

driver.get("https://www.instagram.com/accounts/login/")
time.sleep(5)
USERNAME = "your_username"
PASSWORD = "your_password"

username_input = driver.find_element(By.NAME, "username")
password_input = driver.find_element(By.NAME, "password")

username_input.send_keys(USERNAME)
password_input.send_keys(PASSWORD)
password_input.send_keys(Keys.RETURN)

time.sleep(10)  # Wait for login to complete

driver.get("https://www.instagram.com/reels/")
time.sleep(5)
for i in range(10):  
    try:
        duration_element = driver.find_element(By.XPATH, "//span[contains(@class, 'video-time')]")  # Adjust this if needed
        reel_duration_text = duration_element.text.strip()
        
        minutes, seconds = map(int, reel_duration_text.split(":"))
        reel_duration_seconds = minutes * 60 + seconds

        print(f"Reel {i+1} duration: {reel_duration_seconds} seconds")
        time.sleep(reel_duration_seconds + 2) 

        driver.execute_script("document.body.dispatchEvent(new KeyboardEvent('keydown', {'key': 'ArrowDown'}));")
        time.sleep(2)  # Allow time for the next reel to load

    except Exception as e:
        print(f"Error finding duration for reel {i+1}, skipping... Error: {e}")
        time.sleep(5)  # Default wait if duration not found
        driver.execute_script("document.body.dispatchEvent(new KeyboardEvent('keydown', {'key': 'ArrowDown'}));")
driver.quit()
# Out:
# Error finding duration for reel 1, skipping... Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//span[contains(@class, 'video-time')]"}
#   (Session info: chrome=133.0.6943.127); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00890283+25139]
# 	(No symbol) [0x0081B234]
# 	(No symbol) [0x006F04A3]
# 	(No symbol) [0x00738338]
# 	(No symbol) [0x0073868B]
# 	(No symbol) [0x00780F62]
# 	(No symbol) [0x0075CF84]
# 	(No symbol) [0x0077E6E1]
# 	(No symbol) [0x0075CD36]
# 	(No symbol) [0x0072BD29]
# 	(No symbol) [0x0072D064]
# 	GetHandleVerifier [0x00B9B143+3215603]
# 	GetHandleVerifier [0x00BB22BA+3310186]
# 	GetHandleVerifier [0x00BAC4D2+3286146]
# 	GetHandleVerifier [0x00929C80+654384]
# 	(No symbol) [0x008245BD]
# 	(No symbol) [0x008214A8]
# 	(No symbol) [0x00821647]
# 	(No symbol) [0x00813D20]
# ...

# %%
import time
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from webdriver_manager.chrome import ChromeDriverManager

service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

driver.get("https://www.instagram.com/reels/")
time.sleep(5)  # Wait for page to load

def get_reel_duration():
    try:
        duration_element = driver.find_element(By.XPATH, "//time")
        reel_duration = duration_element.get_attribute("datetime")  # Format: PTxxS (ISO 8601)
        seconds = int(reel_duration.replace("PT", "").replace("S", ""))
        return seconds
    except:
        return 5 

while True:
    reel_time = get_reel_duration()
    print(f"Watching reel for {reel_time} seconds...")
    time.sleep(reel_time)  # Wait for reel to complete
    
   
    webdriver.ActionChains(driver).send_keys(Keys.ARROW_DOWN).perform()
    time.sleep(2)  # Small delay before next reel
# Out:
# Watching reel for 5 seconds...
# Watching reel for 5 seconds...
# Watching reel for 5 seconds...
# Watching reel for 5 seconds...
# Watching reel for 5 seconds...
# Watching reel for 5 seconds...
# Watching reel for 5 seconds...
# Watching reel for 5 seconds...
# Watching reel for 5 seconds...
# Watching reel for 5 seconds...
# Watching reel for 5 seconds...
# Watching reel for 5 seconds...
# Watching reel for 5 seconds...
# Watching reel for 5 seconds...
# Watching reel for 5 seconds...
# Watching reel for 5 seconds...
# Watching reel for 5 seconds...
# Watching reel for 5 seconds...
# Watching reel for 5 seconds...
# Watching reel for 5 seconds...
# Watching reel for 5 seconds...
# Watching reel for 5 seconds...
# Watching reel for 5 seconds...
